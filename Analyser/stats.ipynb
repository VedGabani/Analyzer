# %%
import numpy as npdef stats(arr):    print("1.Sum 2.Mean 3.Median")    ch = int(input("Choice: "))    if ch == 1:        print(np.sum(arr))    elif ch == 2:        print(np.mean(arr))    elif ch == 3:        print(np.median(arr))
