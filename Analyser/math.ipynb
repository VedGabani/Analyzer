# %%
import numpy as npdef math_op(arr):    print("1.Add 2.Sub 3.Mul 4.Div")    ch = int(input("Choice: "))    b = list(map(int, input("Enter second array: ").split()))    arr2 = np.array(b).reshape(arr.shape)    if ch == 1:        print(arr + arr2)    elif ch == 2:        print(arr - arr2)    elif ch == 3:        print(arr * arr2)    elif ch == 4:        print(arr / arr2)
