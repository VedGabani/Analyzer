# %%
import numpy as npdef search_sort(arr):    print("1.Search 2.Sort")    ch = int(input("Choice: "))    if ch == 1:        x = int(input("Enter value: "))        print(np.where(arr == x))    elif ch == 2:        print(np.sort(arr))
